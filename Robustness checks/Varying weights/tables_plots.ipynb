# %% [markdown]
# # Adressing distributional shifts in machine learning: The case of order fulfillment in customized production

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Varying alpha
nonlin = 'rf'
error = 'gaussian'
run = 1

# Plot data 1
capacity = 70 
ratio = 1
mae_adversarial = []
for theta in [1,2,3,4]:
    mae_adversarial_run = []
    for wd_param in [0.8,0.9,1,1.1,1.2]:
        file_name = 'results_final/theta_' + str(theta) + '_run_' + str(run) + '_' + nonlin + '_' + error + "_alpha_" + str(wd_param) + '_capacity_' + str(capacity) + '_cost-ratio_' + str(ratio) + '_final_results.csv'
        df = pd.read_csv(file_name, index_col=0)
        adversarial = df.loc['MAE', 'Adversarial']
        mae_adversarial_run.append(adversarial)
    mae_adversarial.append(mae_adversarial_run)
    
# Plot data 2
capacity = 70 
ratio = 1
mae_adversarial2 = []
for theta in [1,2,3,4]:
    mae_adversarial_run2 = []
    for wd_param in [0.8,0.9,1,1.1,1.2]:
        file_name = 'results_final/theta_' + str(theta) + '_run_' + str(run) + '_' + nonlin + '_' + error + "_alpha_" + str(wd_param) + '_capacity_' + str(capacity) + '_cost-ratio_' + str(ratio) + '_final_results.csv'
        df = pd.read_csv(file_name, index_col=0)
        adversarial = df.loc['Scheduling cost', 'Adversarial']
        mae_adversarial_run2.append(adversarial)
    mae_adversarial2.append(mae_adversarial_run2)
    
# Plot
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2)
fig.set_figheight(24)
fig.set_figwidth(12)
plt.rc('axes', titlesize=17)
plt.rc('axes', labelsize=17)
plt.rc('xtick', labelsize=13)
plt.rc('ytick', labelsize=13)
plt.rc('legend', fontsize=17) 

# Theta 1
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[0][0], mae_adversarial[0][1], mae_adversarial[0][2], mae_adversarial[0][3], mae_adversarial[0][4]])
y_dnn = np.array([23.8,23.8,23.8,23.8,23.8])
ax1.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax1.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
ax1.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax1.set_ylabel('MAE')
ax1.set_title('$\\theta = 1$')
ax1.set_xlabel('$\\alpha$')
ax1.set_ylim(18,25)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[0][0], mae_adversarial2[0][1], mae_adversarial2[0][2], mae_adversarial2[0][3], mae_adversarial2[0][4]])
ax2.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([2933.1,2933.1,2933.1,2933.1,2933.1])
ax2.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax2.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax2.set_ylabel('Scheduling cost')
ax2.set_title('$\\theta = 1$')
ax2.set_xlabel('$\\alpha$')
ax2.set_ylim(2000,3100)

# Theta 2
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[1][0], mae_adversarial[1][1], mae_adversarial[1][2], mae_adversarial[1][3], mae_adversarial[1][4]])
ax3.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([24.4,24.4,24.4,24.4,24.4])
ax3.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax3.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax3.set_ylabel('MAE')
ax3.set_title('$\\theta = 2$')
ax3.set_xlabel('$\\alpha$')
ax3.set_ylim(23.5,24.5)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[1][0], mae_adversarial2[1][1], mae_adversarial2[1][2], mae_adversarial2[1][3], mae_adversarial2[1][4]])
ax4.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([3209.4,3209.4,3209.4,3209.4,3209.4])
ax4.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax4.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax4.set_ylabel('Scheduling cost')
ax4.set_title('$\\theta = 2$')
ax4.set_xlabel('$\\alpha$')
ax4.set_ylim(2600,3300)

# Theta 3
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[2][0], mae_adversarial[2][1], mae_adversarial[2][2], mae_adversarial[2][3], mae_adversarial[2][4]])
ax5.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([27.2,27.2,27.2,27.2,27.2])
ax5.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax5.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax5.set_ylabel('MAE')
ax5.set_title('$\\theta = 3$')
ax5.set_xlabel('$\\alpha$')
ax5.set_ylim(24.5,27.5)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[2][0], mae_adversarial2[2][1], mae_adversarial2[2][2], mae_adversarial2[2][3], mae_adversarial2[2][4]])
ax6.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([3870.9,3870.9,3870.93,3870.9,3870.9])
ax6.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax6.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax6.set_ylabel('Scheduling cost')
ax6.set_title('$\\theta = 3$')
ax6.set_xlabel('$\\alpha$')
ax6.set_ylim(2700,4000)

# Theta 4
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[3][0], mae_adversarial[3][1], mae_adversarial[3][2], mae_adversarial[3][3], mae_adversarial[3][4]])
ax7.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([31.4,31.4,31.4,31.4,31.4])
ax7.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax7.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax7.set_ylabel('MAE')
ax7.set_title('$\\theta = 4$')
ax7.set_xlabel('$\\alpha$')
ax7.set_ylim(26,32)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[3][0], mae_adversarial2[3][1], mae_adversarial2[3][2], mae_adversarial2[3][3], mae_adversarial2[3][4]])
ax8.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([4568.4,4568.4,4568.4,4568.4,4568.4])
ax8.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax8.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax8.set_ylabel('Scheduling cost')
ax8.set_title('$\\theta = 4$')
ax8.set_xlabel('$\\alpha$')
ax8.set_ylim(2800,4700)

lines, labels = ax1.get_legend_handles_labels()
fig.tight_layout(pad=3)
fig.legend(lines, labels, bbox_to_anchor=(0.85, 0), ncol=2)
plt.show()

# fig.savefig("varying_alpha.pdf", bbox_inches='tight')

# %%
# Varying beta
nonlin = 'rf'
error = 'gaussian'
run = 1

# Plot data 1
capacity = 70 
ratio = 1
mae_adversarial = []
for theta in [1,2,3,4]:
    mae_adversarial_run = []
    for gradient_penalty_weight in [0.8,0.9,1,1.1,1.2]:
        file_name = 'results_final/theta_' + str(theta) + '_run_' + str(run) + '_' + nonlin + '_' + error + "_beta_" + str(gradient_penalty_weight) + '_capacity_' + str(capacity) + '_cost-ratio_' + str(ratio) + '_final_results.csv'
        df = pd.read_csv(file_name, index_col=0)
        adversarial = df.loc['MAE', 'Adversarial']
        mae_adversarial_run.append(adversarial)
    mae_adversarial.append(mae_adversarial_run)
    
# Plot data 2
capacity = 70 
ratio = 1
mae_adversarial2 = []
for theta in [1,2,3,4]:
    mae_adversarial_run2 = []
    for gradient_penalty_weight in [0.8,0.9,1,1.1,1.2]:
        file_name = 'results_final/theta_' + str(theta) + '_run_' + str(run) + '_' + nonlin + '_' + error + "_beta_" + str(gradient_penalty_weight) + '_capacity_' + str(capacity) + '_cost-ratio_' + str(ratio) + '_final_results.csv'
        df = pd.read_csv(file_name, index_col=0)
        adversarial = df.loc['Scheduling cost', 'Adversarial']
        mae_adversarial_run2.append(adversarial)
    mae_adversarial2.append(mae_adversarial_run2)
    
# Plot
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2)
fig.set_figheight(24)
fig.set_figwidth(12)
plt.rc('axes', titlesize=17)
plt.rc('axes', labelsize=17)
plt.rc('xtick', labelsize=13)
plt.rc('ytick', labelsize=13)
plt.rc('legend', fontsize=17) 

# Theta 1
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[0][0], mae_adversarial[0][1], mae_adversarial[0][2], mae_adversarial[0][3], mae_adversarial[0][4]])
y_dnn = np.array([23.8,23.8,23.8,23.8,23.8])
ax1.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax1.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
ax1.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax1.set_ylabel('MAE')
ax1.set_title('$\\theta = 1$')
ax1.set_xlabel('$\\beta$')
ax1.set_ylim(18,25)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[0][0], mae_adversarial2[0][1], mae_adversarial2[0][2], mae_adversarial2[0][3], mae_adversarial2[0][4]])
ax2.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([2933.1,2933.1,2933.1,2933.1,2933.1])
ax2.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax2.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax2.set_ylabel('Scheduling cost')
ax2.set_title('$\\theta = 1$')
ax2.set_xlabel('$\\beta$')
ax2.set_ylim(2000,3100)

# Theta 2
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[1][0], mae_adversarial[1][1], mae_adversarial[1][2], mae_adversarial[1][3], mae_adversarial[1][4]])
ax3.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([24.4,24.4,24.4,24.4,24.4])
ax3.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax3.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax3.set_ylabel('MAE')
ax3.set_title('$\\theta = 2$')
ax3.set_xlabel('$\\beta$')
ax3.set_ylim(23.5,24.5)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[1][0], mae_adversarial2[1][1], mae_adversarial2[1][2], mae_adversarial2[1][3], mae_adversarial2[1][4]])
ax4.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([3209.4,3209.4,3209.4,3209.4,3209.4])
ax4.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax4.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax4.set_ylabel('Scheduling cost')
ax4.set_title('$\\theta = 2$')
ax4.set_xlabel('$\\beta$')
ax4.set_ylim(2400,3300)

# Theta 3
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[2][0], mae_adversarial[2][1], mae_adversarial[2][2], mae_adversarial[2][3], mae_adversarial[2][4]])
ax5.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([27.2,27.2,27.2,27.2,27.2])
ax5.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax5.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax5.set_ylabel('MAE')
ax5.set_title('$\\theta = 3$')
ax5.set_xlabel('$\\beta$')
ax5.set_ylim(24.5,27.5)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[2][0], mae_adversarial2[2][1], mae_adversarial2[2][2], mae_adversarial2[2][3], mae_adversarial2[2][4]])
ax6.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([3870.9,3870.9,3870.93,3870.9,3870.9])
ax6.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax6.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax6.set_ylabel('Scheduling cost')
ax6.set_title('$\\theta = 3$')
ax6.set_xlabel('$\\beta$')
ax6.set_ylim(2700,4000)

# Theta 4
x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial[3][0], mae_adversarial[3][1], mae_adversarial[3][2], mae_adversarial[3][3], mae_adversarial[3][4]])
ax7.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([31.4,31.4,31.4,31.4,31.4])
ax7.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax7.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax7.set_ylabel('MAE')
ax7.set_title('$\\theta = 4$')
ax7.set_xlabel('$\\beta$')
ax7.set_ylim(26,32)

x = np.array([0.8, 0.9, 1, 1.1, 1.2])
y = np.array([mae_adversarial2[3][0], mae_adversarial2[3][1], mae_adversarial2[3][2], mae_adversarial2[3][3], mae_adversarial2[3][4]])
ax8.plot(x, y, color='darkblue', marker='s', linestyle='solid', label='Adversarial learning (ours)', linewidth=2, markersize=12)
y_dnn = np.array([4568.4,4568.4,4568.4,4568.4,4568.4])
ax8.plot(x, y_dnn, color='cornflowerblue', linestyle='solid', label='Deep neural network', linewidth=2, markersize=12)
ax8.set_xticks([0.8, 0.9, 1, 1.1, 1.2])
ax8.set_ylabel('Scheduling cost')
ax8.set_title('$\\theta = 4$')
ax8.set_xlabel('$\\beta$')
ax8.set_ylim(2800,4700)

lines, labels = ax1.get_legend_handles_labels()
fig.tight_layout(pad=3)
fig.legend(lines, labels, bbox_to_anchor=(0.85, 0), ncol=2)
plt.show()

#fig.savefig("varying_beta.pdf", bbox_inches='tight')
